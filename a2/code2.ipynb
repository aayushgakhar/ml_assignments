# %% [markdown]
# #### Importing libraries and modules

# %%
import math
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import utils
import importlib
importlib.reload(utils)

sns.set()

# %% [markdown]
# #### 1. Creating dataset

# %%
d = utils.dataset(10000)
df1 = d.get(add_noise=True)
df2 = d.get(add_noise=False)

# %% [markdown]
# #### 2. Plotting dataset

# %%
print('add_noise = True')
df = d.get(add_noise = True)
sns.scatterplot(data = df, x = 'x', y = 'y', hue = 'label')
plt.title('add_noise = True')
plt.show()

print('add_noise = False')
# Out:
# add_noise = True
# add_noise = False

# %%
df = d.get(add_noise = False)
df = df.sample(frac=1)
sns.scatterplot(data = df, x = 'x', y = 'y', hue = 'label')
plt.title('add_noise = False')
df.head()
# Out:
#              x         y  label
# 1783 -0.451134  2.107544      1
# 1912  0.540185  2.158454      1
# 5528  0.174023  2.015258      1
# 9080 -0.737982 -0.674820      0
# 5178 -0.379901  3.925027      1

# %% [markdown]
# #### 3. Perceptron

# %%
# def run_perceptron(df, bias = True, a = 0.1, e=100, plot = False):
    
#     theta, arr = pta.perceptron(df, bias=bias, a=a, epochs=e, plot=plot)

#     return theta, arr

# %%
pta = utils.PTA()
theta1, arr1 = pta.perceptron(df1,a=0.0001, plot = True)
plt.show()
plt.plot(arr1)

# %%
plt.plot(arr1)

# %%
def plot_decision_boundary(df, theta):
    X = df[['x','y']].to_numpy()

    x1 = np.array([min(X[:,0]), max(X[:,0])])
    x2 = -(theta[0] + theta[1]*x1)/theta[2]
    plt.plot(x1,x2,'r-',label = 'Decision Boundary')
    sns.scatterplot(data = df, x = 'x', y='y',hue = 'label')

# %%
plot_decision_boundary(df1, theta1)

# %% [markdown]
# #### 4. bias 0

# %%
theta2, arr2 = pta.perceptron(df1, bias = False)

# %%
plot_decision_boundary(df1, theta2)
plt.show()
plt.plot(arr2)

# %% [markdown]
# #### 5. XOR, AND, and OR property

# %%
X = np.array([[0,0],[0,1],[1,0],[1,1]])

y_xor = np.array([0,1,1,0])
y_and = np.array([0,0,0,1])
y_or = np.array([0,1,1,1])

pta.perceptron(X,y_xor)
PTA.
# Out:
# /home/aayush/ml/a2/utils.py:68: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   X = df[['x','y']].to_numpy()
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-12-c516fcf104bc> in <module>
#       5 y_or = np.array([0,1,1,1])
#       6
# ----> 7 pta.perceptron(X,y_xor)
#       8
#       9
#
# ~/ml/a2/utils.py in perceptron(self, df, a, epochs, bias, plot)
#      66
#      67     def perceptron(self, df, a=0.01, epochs=100, bias=True, plot = False):
# ---> 68         X = df[['x','y']].to_numpy()
#      69         y = df['label'].to_numpy()
#      70         if bias:
#
# ...
