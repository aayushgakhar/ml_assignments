# %% [markdown]
# #### Importing libraries and modules

# %%
import math
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import utils
import importlib
importlib.reload(utils)

sns.set()

# %% [markdown]
# #### 1. Creating dataset

# %%
d = utils.dataset(10000)
df1 = d.get(add_noise=True)
df2 = d.get(add_noise=False)

# %% [markdown]
# #### 2. Plotting dataset

# %%
print('add_noise = True')
sns.scatterplot(data=df1, x='x', y='y', hue='label', style='label')
plt.title('add_noise = True')
# Out:
# add_noise = True
# Text(0.5, 1.0, 'add_noise = True')

# %%
print('add_noise = False')
sns.scatterplot(data=df2, x='x', y='y', hue='label', style='label')
plt.title('add_noise = False')
# Out:
# add_noise = False
# Text(0.5, 1.0, 'add_noise = False')

# %% [markdown]
# #### 3. Perceptron

# %%
def run_perceptron(df, bias=True):
    X = df.drop('label', axis=1).to_numpy()
    y = df['label'].to_numpy()
    perceptron = utils.Perceptron(X.shape[1])
    theta, arr = perceptron.fit(X, y, epochs=100, bias=bias)
    plt.show()
    plt.plot(arr)
    plt.show()
    perceptron.plot_decision_boundary(X, y)
    return theta, arr

# %%
theta, arr = run_perceptron(df1)

# %% [markdown]
# #### 4. bias 0

# %%
theta, arr = run_perceptron(df1, bias=False)

# %% [markdown]
# #### 5. XOR, AND, and OR property

# %%
def f():
    X = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])

    y_xor = np.array([0, 1, 1, 0])
    y_and = np.array([0, 0, 0, 1])
    y_or = np.array([0, 1, 1, 1])

    perceptron = utils.Perceptron(X.shape[1])
    theta_xor, arr_xor = perceptron.fit(X, y_xor, epochs=100, bias=True)
    print(theta_xor)
    perceptron.plot_decision_boundary(X,y_xor)
    plt.show()
    plt.plot(arr_xor)
    plt.show()

    perceptron = utils.Perceptron(X.shape[1])
    theta_and, arr_and = perceptron.fit(X, y_and, epochs=100, bias=True)
    perceptron.plot_decision_boundary(X,y_and)
    plt.show()
    plt.plot(arr_and)
    plt.show()

    perceptron = utils.Perceptron(X.shape[1])
    theta_or, arr_or = perceptron.fit(X, y_or, epochs=100, bias=True)
    perceptron.plot_decision_boundary(X,y_or)
    plt.show()
    plt.plot(arr_or)
    plt.show()

f()
# Out:
# [ 0.     -0.0001  0.    ]
# /home/aayush/ml_assignments/a2/utils.py:99: RuntimeWarning: divide by zero encountered in true_divide
#   plt.plot(x1,x2,'r-',label = 'Decision Boundary')
# /home/aayush/ml_assignments/a2/utils.py:99: RuntimeWarning: invalid value encountered in true_divide
#   plt.plot(x1,x2,'r-',label = 'Decision Boundary')
